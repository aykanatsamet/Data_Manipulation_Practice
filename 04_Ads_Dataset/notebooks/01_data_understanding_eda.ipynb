# %% [markdown]
# # Data Understanding & Exploratory Data Analysis
#
# ## Advertisement Dataset Analysis

# %% [markdown]
# ## Problem Definition
#
# The objective of this project is to analyze user behavior related to online advertisements.
# By understanding the structure and characteristics of the dataset, we aim to prepare the data
# for further exploratory analysis, feature engineering, and predictive modeling.
#
# This notebook focuses on understanding the dataset, identifying potential data quality issues,
# and extracting initial insights.

# %% [markdown]
# ## Dataset Description
#
# The dataset contains anonymized information about users interacting with online advertisements.
# It includes demographic attributes as well as behavioral features such as time spent on ads
# and interaction outcomes.
#
# The dataset is used to explore patterns related to advertisement engagement.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
url = "https://raw.githubusercontent.com/ameenmanna8824/DATASETS/main/Social_Network_Ads.csv"
data = pd.read_csv(url)

# %% [markdown]
# ## Initial Data Inspection
#
# In this section, we take an initial look at the dataset to understand its size,
# structure, and feature types.

# %%
data.shape
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# ## Dataset Structure
#
# Understanding the data types and non-null counts helps identify potential issues
# such as missing values or incorrect data formats.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %% [markdown]
# ## Descriptive Statistics
#
# Descriptive statistics provide an overview of numerical features, helping identify
# distribution characteristics and potential outliers.

# %%
data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [markdown]
# ## Missing Values Analysis
#
# Checking missing values is crucial for determining data cleaning strategies.

# %%
data.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# ## Categorical Feature Overview
#
# Categorical variables are examined to understand class distributions
# and potential imbalance.

# %%
categorical_cols = data.select_dtypes(include="object").columns
data[categorical_cols].nunique()
# Out:
# Gender    2
# dtype: int64

# %% [markdown]
# ## Initial Observations
#
# - The dataset contains both numerical and categorical features.
# - Some numerical variables show skewed distributions.
# - Certain features may require scaling or transformation.
# - Potential data quality issues such as missing values will be addressed
#   in subsequent analysis steps.

# %% [markdown]
# ## Next Steps
#
# - Perform detailed exploratory data analysis (EDA)
# - Handle missing values and outliers
# - Engineer meaningful features for modeling
